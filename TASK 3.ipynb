# %% [markdown]
# # The Sparks Foundation Internship
# # Data Science And Business Analytics
# # Task 3: Exploratory Data Analysis -Retail
#
#
#
# # Name: Vivek Gagiya

# %% [markdown]
# Perform Exploratory Data Analysis on the dataset SampleSuperstore. As a business manager, try to find out the weak areas where you can work to make more profit. What all business problems can you derive by exploring the data?

# %%
# importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the Data
store = pd.read_csv('SampleSuperstore.csv')
store
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#first 10 rows
store.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
#last 10 rows
store.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %% [markdown]
# # Analyzing the Data

# %%
#function to describe the count,mean and percentile
store.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#function for data info
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#checking for the Duplicate rows
print('Number of duplicate rows =', store.duplicated().sum())
# Out:
# Number of duplicate rows = 17

# %%
# removing duplicate rows
store.drop_duplicates(inplace=True)
store
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#check number of rows and columns in dataset
print('Shape of Dataset =', store.shape)
# Out:
# Shape of Dataset = (9977, 13)

# %%
#number of Unique values per column
store.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#Data Correlations
store.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
#Data Covariance
store.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.027732e+09 -469412.768497  935.818272  391.989291
# Sales       -4.694128e+05  389028.396022  278.765576   -3.645637
# Quantity     9.358183e+02     278.765576    4.958001    0.003990
# Discount     3.919893e+02      -3.645637    0.003990    0.042624
# Profit      -2.246799e+05   70057.067126   34.565743  -10.632751
#
#                     Profit
# Postal Code -224679.858643
# Sales         70057.067126
# Quantity         34.565743
# Discount        -10.632751
# Profit        54970.478824

# %%
# plotting the correlations heatmap
plt.figure(figsize = (10,5))
sns.heatmap(store.corr(), annot=True)
plt.title('Correlations Plot', size=20)
plt.show()

# %% [markdown]
# #### from above heatmap we can see that the cities/states having high discounts will have low profits and the cities/states with high sales will have high profits.

# %%
# finding nature of data through histogram plots
store.hist(bins=50 ,figsize=(15,10))
plt.show()

# %% [markdown]
# #### Above Histograms shows the data is not normal it is quite spreadout

# %%
# comparing categories with sub-categories
plt.figure(figsize = (10, 5))
plt.bar('Sub-Category', 'Category', data=store)
plt.title('Category vs Sub-Category', size=25)
plt.xticks(rotation=90, size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# # Profits in States

# %%
# state counts
print('Total number of States are', store['State'].nunique())
print(store['State'].value_counts())
# Out:
# Total number of States are 49
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# ...

# %%
# sorting the profits of states in decreasing order
states_profit = store.groupby(by='State').sum()['Profit'].sort_values(ascending=False).reset_index()

# %%
# plotting top 10 states with highest profits
plt.figure(figsize = (10,5))
plt.title('States with Maximum Profits', size=30)
sns.barplot(x='State', y='Profit', data=states_profit.head(10)) 
plt.xticks(rotation=60, size=15)
plt.yticks(size=15)
plt.xlabel('States', size=20)
plt.ylabel('Profits', size=20)
plt.show()

# %%
# plotting bottom 10 states with least profits
plt.figure(figsize = (10,5))
plt.title('States with Minimum Profits', size=30)
sns.barplot(x='State', y='Profit', data=states_profit.tail(10)) 
plt.xticks(rotation=60, size=15)
plt.yticks(size=15)
plt.xlabel('States', size=20)
plt.ylabel('Profits', size=20)
plt.show()

# %% [markdown]
# #### From above plots we can conclude that the most profitable state is California and the least profitable state is Texas.

# %% [markdown]
# # Profits in Cities

# %%
# sorting the profits of cities in decreasing order
cities_profit = store.groupby(by='City').sum()['Profit'].sort_values(ascending=False).reset_index()

# %%
# plotting top 10 cities with highest profits
plt.figure(figsize = (10,5))
plt.title('Cities with Maximum Profits', size=30)
sns.barplot(x='City', y='Profit', data=cities_profit.head(10)) 
plt.xticks(rotation=60, size=15)
plt.yticks(size=15)
plt.xlabel('Cities', size=20)
plt.ylabel('Profits', size=20)
plt.show()

# %%
# plotting bottom 10 cities with least profits
plt.figure(figsize = (10,5))
plt.title('Cities with Minimum Profits', size=30)
sns.barplot(x='City', y='Profit', data=cities_profit.tail(10)) 
plt.xticks(rotation=60, size=15)
plt.yticks(size=15)
plt.xlabel('Cities', size=20)
plt.ylabel('Profits', size=20)
plt.show()

# %% [markdown]
# # Category Plots

# %%
sns.countplot(x='Category', data=store)
plt.title('Category counts', size=20);

# %% [markdown]
# ### Office Supplies are in high demand. Technology category has the least supply.

# %%
#profits in terms of Categories
category_profit = store.groupby('Category').sum()['Profit'].sort_values(ascending = False)

plt.figure(figsize=(6,6))
plt.title('Profits in terms of Categories', size=20)
category_profit.plot(kind='bar')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# #### Technology category is the most profitable, despite having the least supply. Furniture category gains much less profit as compared to other two sectors.

# %%
#plot sales V/S profit
sales = store.groupby('Category').sum()['Sales'].nlargest(n=10) # top 10 states with highest sales
profits = store.groupby('Category').sum()['Profit'].nlargest(n=10) # top 10 states with highest profits

plt.style.use('seaborn')
sales.plot(kind='bar', fontsize=15, color='c')
profits.plot(kind='bar', fontsize=15, color='m')
plt.xlabel('Categories', fontsize=15)
plt.ylabel('Total Sales and Profits', fontsize=15)
plt.title("Sales vs Profits in terms of Categories", size=15)
plt.show()

# %% [markdown]
# #### Technology and Office Supplies have high sales and profit.

# %% [markdown]
# # Sub-cateogory Plots

# %%
plt.figure(figsize = (16,8))
sns.countplot(x='Sub-Category', data=store)
plt.title('Sub-Category counts', size=20);

# %% [markdown]
# #### We can see that Binders and Paper have very heavy demand. Machines and Copiers have the least demand.

# %%
#profits of Sub-categories
sub_profit = store.groupby('Sub-Category').sum()['Profit'].sort_values(ascending = False)

plt.figure(figsize=(16,6))
plt.title('Profits in terms of Sub-Categories', size=20)
sub_profit.plot(kind='bar')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# #### we observe Copiers have highest profit, while Tables have lowest profit.

# %%
#plotting for losses of sub-category
min_profit = store.groupby('Sub-Category').min()['Profit'].sort_values()

plt.figure(figsize = (8,6))
min_profit.plot()
plt.title('Sub-Categories with Highest Losses', size=20)
plt.xticks(rotation=60, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# #### As we can see in plot Machines have incurred more loss than other sub-categories

# %% [markdown]
# # shipping mode plots

# %%
sns.countplot(x='Ship Mode', data=store)
plt.title('Shipping Mode counts', size=20);

# %%
#plotting profits in Shipping mode
ship_profit = store.groupby('Ship Mode').sum()['Profit'].sort_values(ascending = False)

plt.figure(figsize=(16,6))
plt.title('Profits in terms of Shipping Modes', size=20)
ship_profit.plot(kind='bar')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Standard Class shipping mode shows very high profit as compared to others.

# %%
ship_profit_avg = store.groupby('Ship Mode').mean()['Profit'].sort_values(ascending = False)

plt.figure(figsize=(16,6))
plt.title('Average Profits in terms of Shipping Modes', size=20)
ship_profit_avg.plot(kind='bar')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
#discounts in Shipping Mode
ship_discount = store.groupby('Ship Mode').sum()['Discount'].sort_values(ascending = False).reset_index()

plt.figure(figsize=(10,6))
plt.title('Discounts in terms of Shipping Modes', size=20)
sns.barplot(x='Ship Mode', y='Discount', data=ship_discount)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### We can see Standard Class shipping mode provides maximum discount and gains maximum profit. But the average profit is minimum.

# %% [markdown]
# # Segment Plots

# %%
sns.countplot(x='Segment', data=store)
plt.title('Segment counts', size=20);

# %% [markdown]
# #### Consumer orders are the most and Home Office orders are the least.

# %%
#profits in Segments
segment_profit = store.groupby('Segment').mean()['Profit'].sort_values(ascending = False).reset_index()

plt.figure(figsize=(8,5))
plt.title('Profits according to Segments', size=20)
sns.barplot(x='Segment', y='Profit', data=segment_profit)
plt.xticks(rotation=60 , fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
sales = store.groupby('Segment').mean()['Sales'].sort_values(ascending = False)
profits = store.groupby('Segment').mean()['Profit'].sort_values(ascending = False)

plt.style.use('seaborn')
sales.plot(kind='bar', fontsize=15, color='r')
profits.plot(kind='bar', fontsize=15, color='g')
plt.xlabel('Segments',fontsize=15)
plt.ylabel('Total Sales and Profits', fontsize=15)
plt.title("Sales vs Profits in terms of Segments", size=20)
plt.show()

# %% [markdown]
# #### We observed Home Office segment has more sales and profits, inspite of having less orders. Consumer segment has the least sales and profit.

# %% [markdown]
# # Region Plots

# %%
sns.countplot(x='Region', data=store)
plt.title('Region counts', size=20);

# %% [markdown]
# #### Orders are delivered more in the West and East zones.

# %%
#profits In Regions
regions_profit = store.groupby('Region').sum()['Profit'].sort_values(ascending = False).reset_index()

plt.figure(figsize=(10,5))
plt.title('Profits according to Regions', size=20)
sns.barplot(x='Region', y='Profit', data=regions_profit)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
#plot of sales V/S profits in terms of region
sales = store.groupby('Region').sum()['Sales'].sort_values(ascending = False)
profits = store.groupby('Region').sum()['Profit'].sort_values(ascending = False)

plt.style.use('seaborn')
sales.plot(kind='bar', fontsize=15, color='b')
profits.plot(kind='bar', fontsize=15, color='y')
plt.xlabel('Regions', fontsize=15)
plt.ylabel('Total Sales and Profits', fontsize=15)
plt.title("Sales vs Profits in terms of Regions", size=20)
plt.show()

# %% [markdown]
# ### we can see West and East zones are more dominant in terms of sales as well as profits.

# %% [markdown]
# # Sales,Profits and Discounts

# %%
#profit V/S discount
plt.figure(figsize=(10,6))
sns.lineplot(x='Discount', y='Profit', data=store, label='Discount')
plt.title("Profit vs Discount", size=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Plot shows negative correlation between Profit and Discount.

# %%
#profit V/s sales
sns.lineplot(x='Sales', y='Profit', data=store)
plt.title("Profit vs Sales", size=20)
plt.show()

# %% [markdown]
# ### Profit and Sales have a moderately strong correlation.

# %%
#plot for sales V/s profit in top 10 states
sales = store.groupby('State').sum()['Sales'].nlargest(n=10) # top 10 states with highest sales
profits = store.groupby('State').sum()['Profit'].nlargest(n=10) # top 10 states with highest profits

sales.plot(kind='bar', fontsize=15, color='purple')
profits.plot(kind='bar', fontsize=15 , color='pink')
plt.xlabel('States', fontsize=15)
plt.ylabel('Total sales and profits', fontsize=15)
plt.title("Sales vs Profit in States", size=20)
plt.show()

# %% [markdown]
# #### From the plot, we find that California and New York states have the highest sales and profits.

# %%
#plot for sales V/s profit with Discount
plt.style.use('seaborn')
store.plot(kind="scatter", x="Sales", y="Profit", c="Discount", s=20, fontsize=16, colormap="Spectral")
plt.ylabel('Total Profits', fontsize=15)
plt.title("Sales vs Profits on Discounts", fontsize=20)
plt.show()

# %% [markdown]
# #### From the above plot we can conclude that Sales increase diminishingly with increase in discounts, but profit decreases drastically.

# %% [markdown]
# # Final Coclusions

# %% [markdown]
# ### Q. As a business manager, try to find out the weak areas where you can work to make more profit.

# %% [markdown]
# ##### 1. To increase profits, we have to increase the amount of sales.
# ##### 2. We need to improvise the strategy to increase sales and profit in the least profitable states like Texas, Ohio and Pennsylvania, and the least profitable cities like Philadelphia and Houston. We can also work upon expanding profits in the states of Los Angeles and Seattle.

# %% [markdown]
# ##### 3. We should decrease discounts in Standard Class shipping to scale up the average profit.
# ##### 4. We can also increase sales in Consumer segment to increase profits as Consumer orders are more.
# ##### 5. we can see that, Catagory "Furniture" is the weak catagory with minimal profits and good amount of loss. Stratergies should be made to sell these catagories more and make more profit than loss.

# %% [markdown]
# ### Q. What all business problems you can derive by exploring the data?

# %% [markdown]
# ##### 1. We should also focus on making amends for the loss incurred in Machines sub-category.
# ##### 2. the big states such as California and New york does not depend much on Discounts, the other states are affected badly if No discounts are given. The other thing to understand is, as seen before discounts in products are reducing a lot of profits and half of times loss is suffered. Thus this is a major business problem.
# ##### 3. Only a few states have a considerable amount of Furniture purchased. One catagory not performing well in a business can affect the entire business thus this can lead to a business problem. Although mostly all the have ordered Technology related products, the sales are still considerable low.
# ##### 4. It can be clearly seen that the Southern states have the lowest purchase.
# ##### 5.Low customer purchase can become a major business problem as it can completely remove the business from that state.
# ##### 6.Although all the other 3 regions are doing well, there are few states which have almost No sales or a very minimal amount of purchase noted.
